# %% [markdown]
# # Pipline for Breast Cancer data set

# %%
# imports 
import os
import pandas as pd
import numpy as np

# %%
# load csv file into df 
df = pd.read_csv("data/breast-cancer-diagnostic.shuf.lrn.csv")

# %% [markdown]
# ## Imputation

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class OutlierImputer(BaseEstimator, TransformerMixin):
    """
    Ersetzt Ausreißer (Z-Score > threshold) durch den Median
    der jeweiligen Spalte (berechnet aus Trainingsdaten).
    """
    def __init__(self, threshold=3):
        self.threshold = threshold
        self.medians_ = None
        self.numeric_cols_ = None

    def fit(self, X, y=None):
        # Nur numerische Spalten
        self.numeric_cols_ = X.select_dtypes(include='number').columns
        # 
        self.medians_ = X[self.numeric_cols_].median()
        return self

    def transform(self, X, y=None):
        # Kopie, um Original-Daten nicht zu überschreiben
        X_transformed = X.copy()
        for col in self.numeric_cols_:
            mean = X_transformed[col].mean()
            std = X_transformed[col].std()

            # Z-Scores
            z_scores = (X_transformed[col] - mean) / (std if std != 0 else 1e-9)
            outlier_idx = np.where(np.abs(z_scores) > self.threshold)[0]  # int positions

            # Outlier -> Median
            X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]

            z_scores = (X_transformed[col] - mean) / (std if std != 0 else 1e-9)
            
        return X_transformed

# %% [markdown]
# ## Pipline

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier


pipeline = Pipeline([
    ('outlier_imputer', OutlierImputer(threshold=3)),
    ('smote', SMOTE(random_state=123)),          # Minority Over-Sampling
    ('scaler', StandardScaler()),               # StandardScaler
    ('pca', PCA(n_components=0.95)),            # PCA mit 95% Varianzerhalt
    ('classifier', RandomForestClassifier())    # random frorest
])

# %% [markdown]
# ## Cross Validation
# Vorteil: In jedem Fold wird erst der Outlier-Imputer „gefitet“, dann SMOTE auf den jeweiligen Fold angewendet, anschließend skaliert, PCA berechnet und zuletzt das Modell trainiert. Auf dem Test-Fold werden alle Transformationen mit den Parametern des Trainingsfolds angewandt. Dadurch vermeidest du jegliches Data Leakage.

# %% [markdown]
# ## Optimazation

# %%
def objective(trial):
    # === Hyperparameter per trial vorschlagen
    threshold = trial.suggest_float("outlier_threshold", 2.0, 5.0)  # Range für Outlier
    n_estimators = trial.suggest_int("n_estimators", 50, 300)
    max_depth = trial.suggest_int("max_depth", 3, 20)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 10)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 4)
    max_features = trial.suggest_categorical("max_features", ["sqrt", "log2"])
    pca_n_components = trial.suggest_float("pca_n_components", 0.90, 0.99)

    # === Pipeline zusammenbauen ===
    pipeline = Pipeline([
        ("outlier_imputer", OutlierImputer(threshold=threshold)),
        ("smote", SMOTE(random_state=42)),
        ("scaler", StandardScaler()),
        ("pca", PCA(n_components=pca_n_components)),
        ("rf", RandomForestClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            max_features=max_features,
            random_state=42,
            n_jobs=-1
        ))
    ])

    # === Cross Validation ===
    # Die rohen X und y (nicht vorher skaliert/PCA etc.)
    cv_score = cross_val_score(
        pipeline, 
        X, 
        y, 
        cv=5,                # z.B. 5-Fold CV
        scoring='f1_macro'   # oder f1_weighted, accuracy, etc.
    ).mean()

    return cv_score

# === Optuna Study starten ===
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

# Ergebnis
print("Beste Parameter:", study.best_params)
print("Bester Score:", study.best_value)

# Optional: Visualisierungen
# fig1 = optuna.visualization.plot_optimization_history(study)
# fig1.show()
# Out:
# [I 2025-04-16 13:10:36,601] A new study created in memory with name: no-name-46d98217-a959-4e11-acd4-a81d7d331d6e
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:37,462] Trial 0 finished with value: 0.9340752917197955 and parameters: {'outlier_threshold': 4.477169652736231, 'n_estimators': 127, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'log2', 'pca_n_components': 0.9173255125319805}. Best is trial 0 with value: 0.9340752917197955.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:39,123] Trial 1 finished with value: 0.9343095685244032 and parameters: {'outlier_threshold': 4.403239193128821, 'n_estimators': 294, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2', 'pca_n_components': 0.9642673609815939}. Best is trial 1 with value: 0.9343095685244032.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:40,468] Trial 2 finished with value: 0.9413388725537072 and parameters: {'outlier_threshold': 2.2913084351079456, 'n_estimators': 206, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'pca_n_components': 0.9019024833730107}. Best is trial 2 with value: 0.9413388725537072.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:41,493] Trial 3 finished with value: 0.9267329773527567 and parameters: {'outlier_threshold': 3.4641685112811125, 'n_estimators': 151, 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'pca_n_components': 0.9371998825727139}. Best is trial 2 with value: 0.9413388725537072.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:43,227] Trial 4 finished with value: 0.9415232107380455 and parameters: {'outlier_threshold': 3.097376875939277, 'n_estimators': 266, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'log2', 'pca_n_components': 0.9120015204771429}. Best is trial 4 with value: 0.9415232107380455.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:44,280] Trial 5 finished with value: 0.945051970266805 and parameters: {'outlier_threshold': 2.375406127691573, 'n_estimators': 162, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'pca_n_components': 0.9409660457411743}. Best is trial 5 with value: 0.945051970266805.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:45,161] Trial 6 finished with value: 0.9342549624697971 and parameters: {'outlier_threshold': 2.8589715356521177, 'n_estimators': 109, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'log2', 'pca_n_components': 0.9762539826249073}. Best is trial 5 with value: 0.945051970266805.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:46,139] Trial 7 finished with value: 0.9343095685244032 and parameters: {'outlier_threshold': 4.016422620781249, 'n_estimators': 145, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2', 'pca_n_components': 0.970237182063842}. Best is trial 5 with value: 0.945051970266805.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:46,986] Trial 8 finished with value: 0.9307903914464315 and parameters: {'outlier_threshold': 4.267878261903178, 'n_estimators': 118, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'pca_n_components': 0.9713135611645027}. Best is trial 5 with value: 0.945051970266805.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:47,947] Trial 9 finished with value: 0.9343095685244032 and parameters: {'outlier_threshold': 3.0842588088896075, 'n_estimators': 154, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'pca_n_components': 0.9156703347380905}. Best is trial 5 with value: 0.945051970266805.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:48,582] Trial 10 finished with value: 0.9332192144340491 and parameters: {'outlier_threshold': 2.100846447791649, 'n_estimators': 74, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'pca_n_components': 0.9444459475412513}. Best is trial 5 with value: 0.945051970266805.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:49,965] Trial 11 finished with value: 0.9338580710729056 and parameters: {'outlier_threshold': 2.5237679411874123, 'n_estimators': 229, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'pca_n_components': 0.9283447712767301}. Best is trial 5 with value: 0.945051970266805.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:51,624] Trial 12 finished with value: 0.9339867432263022 and parameters: {'outlier_threshold': 3.5130877102733375, 'n_estimators': 275, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'pca_n_components': 0.9564174747531263}. Best is trial 5 with value: 0.945051970266805.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:53,148] Trial 13 finished with value: 0.9266444288592635 and parameters: {'outlier_threshold': 2.715881289131799, 'n_estimators': 243, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2', 'pca_n_components': 0.9884779176610946}. Best is trial 5 with value: 0.945051970266805.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:54,396] Trial 14 finished with value: 0.9452258522258523 and parameters: {'outlier_threshold': 3.3025959088240784, 'n_estimators': 195, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'pca_n_components': 0.9099093925024171}. Best is trial 14 with value: 0.9452258522258523.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:55,604] Trial 15 finished with value: 0.9379622713919407 and parameters: {'outlier_threshold': 3.715924360538446, 'n_estimators': 188, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'pca_n_components': 0.9306806091042794}. Best is trial 14 with value: 0.9452258522258523.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:10:56,780] Trial 16 finished with value: 0.9305006811204606 and parameters: {'outlier_threshold': 4.963253145723566, 'n_estimators': 186, 'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'log2', 'pca_n_components': 0.9531032664029725}. Best is trial 14 with value: 0.9452258522258523.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:11:06,543] Trial 24 finished with value: 0.9417711587958832 and parameters: {'outlier_threshold': 3.3267630156277552, 'n_estimators': 295, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'log2', 'pca_n_components': 0.9060174678876816}. Best is trial 14 with value: 0.9452258522258523.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:11:08,177] Trial 25 finished with value: 0.92976452100408 and parameters: {'outlier_threshold': 2.625236472718033, 'n_estimators': 294, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 'log2', 'pca_n_components': 0.9091322634334238}. Best is trial 14 with value: 0.9452258522258523.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:11:09,222] Trial 26 finished with value: 0.9264137726533317 and parameters: {'outlier_threshold': 3.6570623452047166, 'n_estimators': 169, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'pca_n_components': 0.92091331041146}. Best is trial 14 with value: 0.9452258522258523.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:11:10,605] Trial 27 finished with value: 0.9268929555489956 and parameters: {'outlier_threshold': 3.3002690945259427, 'n_estimators': 233, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'log2', 'pca_n_components': 0.9058553493580501}. Best is trial 14 with value: 0.9452258522258523.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:11:11,511] Trial 28 finished with value: 0.9419096459096459 and parameters: {'outlier_threshold': 4.016261919437096, 'n_estimators': 137, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'pca_n_components': 0.9333938564132552}. Best is trial 14 with value: 0.9452258522258523.
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '901034.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '904745.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# /var/folders/rf/g2w9ss695fj3vt63jtcdpjbr0000gn/T/ipykernel_86248/350205609.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '905609.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_transformed.iloc[outlier_idx, X_transformed.columns.get_loc(col)] = self.medians_[col]
# [I 2025-04-16 13:11:12,366] Trial 29 finished with value: 0.9377883894328933 and parameters: {'outlier_threshold': 4.69730432902578, 'n_estimators': 134, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'pca_n_components': 0.9360446718527798}. Best is trial 14 with value: 0.9452258522258523.
# Beste Parameter: {'outlier_threshold': 3.3025959088240784, 'n_estimators': 195, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'pca_n_components': 0.9099093925024171}
# Bester Score: 0.9452258522258523
